# %%
# project specific
import numpy as np
import matplotlib.pyplot as plt
import os
import functions as fitpatterns
import itertools
import probCMR as CMR2_simple
import functions as functions

# %% [markdown]
# ### Simulate the model once to obtain lists of recall

# %%
N = 0
ll = 16
lag_examine = 4
data_id = 0 
CMR_sp = fitpatterns.model_probCMR(N,ll,lag_examine,0)
print(CMR_sp[0:10])
# Out:
# [[2, 0, 1, 3, 5, 6, 10, 13, 11, 7, 4], [0, 6, 1, 5, 4, 9, 12, 10, 14], [1, 13, 10, 5, 12, 0, 2, 8, 9, 14, 15], [3, 11, 13, 7, 9, 10, 14, 0, 1, 8, 4, 5, 15, 2], [0, 2, 4, 6, 7, 8], [10, 12, 13, 7, 15, 3], [0, 1, 2, 5], [6, 1, 3, 5, 4, 2, 15, 0, 8, 11, 10, 12, 9], [15, 2, 4, 11, 1, 8, 3], [3, 4, 7, 12, 8, 5, 1, 2]]

# %% [markdown]
# ### Obtain the likelihood of the model given human data and model parameters

# %%
N = 1
ll = 16
lag_examine = 4
data_id = 0 
lkh = fitpatterns.model_probCMR(N,ll,lag_examine,data_id)
print(lkh)
# Out:
# -8482.670410520856

# %%
N = 1
ll = 10
lag_examine = 4
data_id = 1 
lkh = fitpatterns.model_probCMR(N,ll,lag_examine,data_id)
print(lkh)
# Out:
# -15822.511238487703

# %% [markdown]
# ### Simulate the model multiple times to plot data

# %%
N = 3
ll = 16
lag_examine = 4
data_id = 0
RMSE = fitpatterns.model_probCMR(N,ll,lag_examine,data_id)
print(RMSE)
# Out:
# -0.9326285591343615

# %%
N = 3
ll = 10
lag_examine = 4
data_id = 1
RMSE = fitpatterns.model_probCMR(N,ll,lag_examine,data_id)
print(RMSE)
# Out:
# -0.8197908247684242
