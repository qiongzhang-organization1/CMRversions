# %%
## project specific
import numpy as np
import matplotlib.pyplot as plt
import os
import itertools
import time


from probCMR import CMR2
from functions import init_functions
Functions = init_functions(CMR2, "")
functions = Functions()

# %% [markdown]
# ### Simulate the model once to obtain lists of recall

# %%
N = 0
ll = 16
lag_examine = 4
data_id = 0 
CMR_sp = functions.model_probCMR(N,ll,lag_examine,0)
print(CMR_sp[0:10])
# Out:
# [[0, 1, 2, 4, 6, 8, 11, 15, 12, 13, 14], [1, 2, 4, 0, 3, 12, 15, 8, 13], [4, 11, 15, 3, 6, 1, 5, 12, 0, 10, 7], [10, 12, 3, 13], [9, 15, 10, 11, 12, 0, 13, 14], [0, 2, 14, 15, 9, 13, 11, 4, 6, 12, 8], [0, 1, 13, 9, 5, 14, 15, 11, 12], [3, 10, 6, 4, 0, 7, 1, 9, 14, 15], [14, 0, 1, 2, 4, 13, 5, 7, 10, 15, 6], [1, 13, 2, 4, 3, 0, 7, 8]]

# %% [markdown]
# ### Obtain the likelihood of the model given human data and model parameters

# %%
N = 1
ll = 16
lag_examine = 4
data_id = 0 
lkh = functions.model_probCMR(N,ll,lag_examine,data_id)
print(lkh)
# Out:
# -8482.670410520856

# %%
N = 1
ll = 10
lag_examine = 4
data_id = 1 
lkh = functions.model_probCMR(N,ll,lag_examine,data_id)
print(lkh)
# Out:
# -15822.511238487703

# %% [markdown]
# ### Simulate the model multiple times to plot data

# %%
t0
# Out:
# 544.87

# %%
t0= time.time()

N = 3
ll = 16
lag_examine = 4
data_id = 0
RMSE = functions.model_probCMR(N,ll,lag_examine,data_id)
print(RMSE)

print(time.time()-t0)
# Out:
# -0.7598757842207493
# 20.535895109176636

# %%
t0= time.time()

N = 3
ll = 10
lag_examine = 4
data_id = 1
RMSE = functions.model_probCMR(N,ll,lag_examine,data_id)
print(RMSE)

print(time.time()-t0)
# Out:
# -0.8719653929894267
# 8.731749057769775
