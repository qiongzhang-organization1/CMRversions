# %%
## project specific
import numpy as np
import matplotlib.pyplot as plt
import os
import itertools
import time


from probCMR import CMR2
from functions import init_functions
Functions = init_functions(CMR2, "")
functions = Functions()

# %% [markdown]
# ### Simulate the model once to obtain lists of recall

# %%
N = 0
ll = 16
lag_examine = 4
data_id = 0 
CMR_sp = functions.model_probCMR(N,ll,lag_examine,0)
print(CMR_sp[0:10])
# Out:
# [[0, 3, 6, 11, 13, 9, 10, 14], [6, 14, 4, 0, 1, 7, 9, 12, 3, 8, 15, 2], [4, 0, 2, 10, 11, 8, 15, 12, 9, 14, 5], [14, 15, 0, 6, 1, 5, 9, 3, 7, 8], [0, 2, 11, 4, 3, 6, 9, 13, 14, 15], [15, 12, 11, 13, 10, 9, 6, 4, 2, 0, 7], [0, 5, 6, 7, 1, 2, 9, 3, 10], [0, 1, 2, 7, 15, 13, 5, 4, 8, 11, 14, 10], [13, 2, 3, 6, 14, 11, 1, 5, 8], [14, 3, 9, 10, 11, 0, 2, 4, 13, 6, 8, 7, 12]]

# %% [markdown]
# ### Obtain the likelihood of the model given human data and model parameters

# %%
N = 1
ll = 16
lag_examine = 4
data_id = 0 
lkh = functions.model_probCMR(N,ll,lag_examine,data_id)
print(lkh)
# Out:
# -8482.670410520856

# %%
N = 1
ll = 10
lag_examine = 4
data_id = 1 
lkh = functions.model_probCMR(N,ll,lag_examine,data_id)
print(lkh)
# Out:
# -15822.511238487703

# %% [markdown]
# ### Simulate the model multiple times to plot data

# %%
t0
# Out:
# 544.87

# %%
t0= time.time()

N = 3
ll = 16
lag_examine = 4
data_id = 0
RMSE = functions.model_probCMR(N,ll,lag_examine,data_id)
print(RMSE)

print(time.time()-t0)
# Out:
# -0.9810470738463646
# 20.780556201934814

# %%
t0= time.time()

N = 3
ll = 10
lag_examine = 4
data_id = 1
RMSE = functions.model_probCMR(N,ll,lag_examine,data_id)
print(RMSE)

print(time.time()-t0)
# Out:
# -0.8253401229388182
# 8.217766761779785
