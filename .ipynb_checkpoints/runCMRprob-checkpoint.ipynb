# %%
# project specific
import numpy as np
import matplotlib.pyplot as plt
import os
import functions as fitpatterns
import itertools
import probCMR as CMR2_simple
import functions as functions

# %% [markdown]
# ### Simulate the model once to obtain lists of recall

# %%
N = 0
ll = 16
lag_examine = 4
CMR_sp = fitpatterns.model_probCMR(N,ll,lag_examine)
print(CMR_sp[0:10])
# Out:
# [[0, 1, 2, 3, 15, 5, 4, 10, 12, 8, 9], [0, 1, 8, 9, 13, 11, 4, 5, 6, 7], [12, 6, 8, 14, 4, 5, 3, 7, 9, 2], [0, 14, 2, 8, 10, 11, 1, 13, 15, 7, 5], [5, 15, 10, 11, 2, 4, 0, 6, 1], [0, 1, 4, 6, 8, 9, 12, 3, 13], [0, 2, 1, 3, 14, 9, 15, 12, 13, 10], [0, 1, 3, 6, 7, 11, 12, 8, 2, 10], [11, 13, 5, 1, 12, 4, 10, 15, 7, 3], [9, 4, 14, 15, 3, 10, 0, 1, 2]]

# %% [markdown]
# ### Obtain the likelihood of the model given human data and model parameters

# %%
N = 1
ll = 16
lag_examine = 4
lkh = fitpatterns.model_probCMR(N,ll,lag_examine)
print(lkh)
# Out:
# -8482.670410520856

# %% [markdown]
# ### Simulate the model multiple times to plot data

# %%
N = 3
ll = 16
lag_examine = 4
RMSE = fitpatterns.model_probCMR(N,ll,lag_examine)
print(RMSE)
# Out:
# -0.9681590375994944
